# %% [markdown]
# # Python Stats and Plotting Tutorial Assignment

# %% [markdown]
# ## BSGP 2023

# %% [markdown]
# ### Import necessary packages

# %%
from matplotlib import pyplot as plt
import numpy as np
import os
import pandas
from pandas import plotting 
from scipy import stats
import seaborn
from statsmodels.formula.api import ols
import statsmodels.formula.api as smf
import urllib.request

# %% [markdown]
# ## The pandas data-frame

# %% [markdown]
# ### Reading from a CSV file

# %%
data = pandas.read_csv('brain_size.csv', sep=';', na_values='.')
data
# Out:
#     Unnamed: 0  Gender  FSIQ  VIQ  PIQ  Weight  Height  MRI_Count
# 0            1  Female   133  132  124   118.0    64.5     816932
# 1            2    Male   140  150  124     NaN    72.5    1001121
# 2            3    Male   139  123  150   143.0    73.3    1038437
# 3            4    Male   133  129  128   172.0    68.8     965353
# 4            5  Female   137  132  134   147.0    65.0     951545
# 5            6  Female    99   90  110   146.0    69.0     928799
# 6            7  Female   138  136  131   138.0    64.5     991305
# 7            8  Female    92   90   98   175.0    66.0     854258
# 8            9    Male    89   93   84   134.0    66.3     904858
# 9           10    Male   133  114  147   172.0    68.8     955466
# 10          11  Female   132  129  124   118.0    64.5     833868
# 11          12    Male   141  150  128   151.0    70.0    1079549
# 12          13    Male   135  129  124   155.0    69.0     924059
# ...

# %% [markdown]
# ### Creating from arrays

# %%
t = np.linspace(-6, 6, 20)
sin_t = np.sin(t)
cos_t = np.cos(t)

# %% [markdown]
# #### Expose them as a pandas.DataFrame

# %%
pandas.DataFrame({'t': t, 'sin': sin_t, 'cos': cos_t})
# Out:
#            t       sin       cos
# 0  -6.000000  0.279415  0.960170
# 1  -5.368421  0.792419  0.609977
# 2  -4.736842  0.999701  0.024451
# 3  -4.105263  0.821291 -0.570509
# 4  -3.473684  0.326021 -0.945363
# 5  -2.842105 -0.295030 -0.955488
# 6  -2.210526 -0.802257 -0.596979
# 7  -1.578947 -0.999967 -0.008151
# 8  -0.947368 -0.811882  0.583822
# 9  -0.315789 -0.310567  0.950551
# 10  0.315789  0.310567  0.950551
# 11  0.947368  0.811882  0.583822
# 12  1.578947  0.999967 -0.008151
# 13  2.210526  0.802257 -0.596979
# 14  2.842105  0.295030 -0.955488
# 15  3.473684 -0.326021 -0.945363
# 16  4.105263 -0.821291 -0.570509
# 17  4.736842 -0.999701  0.024451
# 18  5.368421 -0.792419  0.609977
# 19  6.000000 -0.279415  0.960170

# %% [markdown]
# ### Manipulating data

# %%
data.shape # 40 rows and 8 columns 
data.columns # It has columns
# Out:
# Index(['Unnamed: 0', 'Gender', 'FSIQ', 'VIQ', 'PIQ', 'Weight', 'Height',
#        'MRI_Count'],
#       dtype='object')

# %%
print(data['Gender']) # Columns can be addressed by name
# Out:
# 0     Female
# 1       Male
# 2       Male
# 3       Male
# 4     Female
# 5     Female
# 6     Female
# 7     Female
# 8       Male
# 9       Male
# 10    Female
# 11      Male
# 12      Male
# 13    Female
# 14    Female
# 15    Female
# 16    Female
# 17      Male
# 18    Female
# 19      Male
# 20      Male
# 21      Male
# 22    Female
# 23      Male
# 24    Female
# 25      Male
# 26    Female
# 27      Male
# 28    Female
# 29    Female
# 30    Female
# 31      Male
# 32      Male
# 33      Male
# 34    Female
# 35    Female
# 36      Male
# 37    Female
# 38      Male
# 39      Male
# Name: Gender, dtype: object

# %%
# Simple Selector
data[data['Gender'] == 'Female']['VIQ'].mean()
# Out:
# 109.45

# %% [markdown]
# ### Using groupby, which splits a dataframe on values of categorical variables

# %%
groupby_gender = data.groupby('Gender')
for gender, value in groupby_gender['VIQ']:
    print((gender, value.mean()))
# Out:
# ('Female', 109.45)
# ('Male', 115.25)

# %%
groupby_gender.mean()
# Out:
#         Unnamed: 0   FSIQ     VIQ     PIQ      Weight     Height  MRI_Count
# Gender
# Female       19.65  111.9  109.45  110.45  137.200000  65.765000   862654.6
# Male         21.35  115.0  115.25  111.60  166.444444  71.431579   954855.4

# %% [markdown]
# ### Plotting data

# %% [markdown]
# #### Scatter matrices

# %%
plotting.scatter_matrix(data[['Weight', 'Height', 'MRI_Count']])
# Out:
# array([[<Axes: xlabel='Weight', ylabel='Weight'>,
#         <Axes: xlabel='Height', ylabel='Weight'>,
#         <Axes: xlabel='MRI_Count', ylabel='Weight'>],
#        [<Axes: xlabel='Weight', ylabel='Height'>,
#         <Axes: xlabel='Height', ylabel='Height'>,
#         <Axes: xlabel='MRI_Count', ylabel='Height'>],
#        [<Axes: xlabel='Weight', ylabel='MRI_Count'>,
#         <Axes: xlabel='Height', ylabel='MRI_Count'>,
#         <Axes: xlabel='MRI_Count', ylabel='MRI_Count'>]], dtype=object)

# %%
plotting.scatter_matrix(data[['PIQ', 'VIQ', 'FSIQ']])
# Out:
# array([[<Axes: xlabel='PIQ', ylabel='PIQ'>,
#         <Axes: xlabel='VIQ', ylabel='PIQ'>,
#         <Axes: xlabel='FSIQ', ylabel='PIQ'>],
#        [<Axes: xlabel='PIQ', ylabel='VIQ'>,
#         <Axes: xlabel='VIQ', ylabel='VIQ'>,
#         <Axes: xlabel='FSIQ', ylabel='VIQ'>],
#        [<Axes: xlabel='PIQ', ylabel='FSIQ'>,
#         <Axes: xlabel='VIQ', ylabel='FSIQ'>,
#         <Axes: xlabel='FSIQ', ylabel='FSIQ'>]], dtype=object)

# %% [markdown]
# ## Hypothesis testing: comparing two groups

# %% [markdown]
# ### 1- sample t test: testing the value of a population mean

# %%
stats.ttest_1samp(data['VIQ'], 0)
# Out:
# TtestResult(statistic=30.08809997084933, pvalue=1.3289196468727879e-28, df=39)

# %% [markdown]
# ### 2- sample t test: testing for difference across populations

# %%
female_viq = data[data['Gender'] == 'Female']['VIQ']
male_viq = data[data['Gender'] == 'Male']['VIQ']
stats.ttest_ind(female_viq, male_viq)
# Out:
# TtestResult(statistic=-0.7726161723275012, pvalue=0.44452876778583217, df=38.0)

# %% [markdown]
# ### Paired tests: repeated measurements on the same individuals

# %%
stats.ttest_ind(data['FSIQ'], data['PIQ'])
# Out:
# TtestResult(statistic=0.465637596380964, pvalue=0.6427725009414841, df=78.0)

# %% [markdown]
# #### But we need to remember that there are links between observations: FSIQ and PIQ

# %% [markdown]
# #### Variance due to inter-subject variability is confounding, and can be removed using "paired test" or "repeated measures test"

# %%
stats.ttest_rel(data['FSIQ'], data['PIQ'])
# Out:
# TtestResult(statistic=1.7842019405859857, pvalue=0.08217263818364236, df=39)

# %% [markdown]
# #### This is equivalent to a 1-sample test on the difference

# %%
stats.ttest_1samp(data['FSIQ'] - data['PIQ'], 0)
# Out:
# TtestResult(statistic=1.7842019405859857, pvalue=0.08217263818364236, df=39)

# %% [markdown]
# #### T-tests assume Gaussian errors. So we can use a Wilcoxon signed-rank test for this:

# %%
stats.wilcoxon(data['FSIQ'], data['PIQ'])
# Out:
# /srv/conda/envs/notebook/lib/python3.9/site-packages/scipy/stats/_morestats.py:4088: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# WilcoxonResult(statistic=274.5, pvalue=0.10659492713506856)

# %% [markdown]
# ## "Formulas" to specify statistical models in Python

# %% [markdown]
# ### Generate simulated data according to the model

# %%
x = np.linspace(-5, 5, 20)
np.random.seed(1)
# normal distribution noise 
y = -5 + 3*x + 4 * np.random.normal(size = x.shape)
# Create a data frame containing all the relevant variables
data = pandas.DataFrame({'x': x, 'y': y})

# %% [markdown]
# ### Specify an OLS model and fit it

# %%
model = ols("y ~ x", data).fit()

# %% [markdown]
# ### Examine the statistics derived from the fit

# %%
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.804
# Model:                            OLS   Adj. R-squared:                  0.794
# Method:                 Least Squares   F-statistic:                     74.03
# Date:                Tue, 18 Jul 2023   Prob (F-statistic):           8.56e-08
# Time:                        17:06:35   Log-Likelihood:                -57.988
# No. Observations:                  20   AIC:                             120.0
# Df Residuals:                      18   BIC:                             122.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -5.5335      1.036     -5.342      0.000      -7.710      -3.357
# ...

# %% [markdown]
# ### Categorical variables: comparing groups or multiple categories

# %%
data = pandas.read_csv('brain_size.csv', sep=';', na_values=".")

# %% [markdown]
# ### Comparison between IQ of male and female using a linear model

# %%
model = ols("VIQ ~ Gender + 1", data).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    VIQ   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.5969
# Date:                Tue, 18 Jul 2023   Prob (F-statistic):              0.445
# Time:                        17:06:36   Log-Likelihood:                -182.42
# No. Observations:                  40   AIC:                             368.8
# Df Residuals:                      38   BIC:                             372.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept        109.4500      5.308     20.619      0.000      98.704     120.196
# ...

# %% [markdown]
# #### An integer column can be forced to be treated as categorical using this line of code

# %%
model = ols('VIQ ~ C(Gender)', data).fit()

# %% [markdown]
# ### Link to t-tests between different FSIQ and PIQ

# %%
data_fisq = pandas.DataFrame({'iq': data['FSIQ'], 'type': 'fsiq'})
data_piq = pandas.DataFrame({'iq': data['PIQ'], 'type': 'piq'})
data_long = pandas.concat((data_fisq, data_piq))
print(data_long)
# Out:
#      iq  type
# 0   133  fsiq
# 1   140  fsiq
# 2   139  fsiq
# 3   133  fsiq
# 4   137  fsiq
# ..  ...   ...
# 35  128   piq
# 36  124   piq
# 37   94   piq
# 38   74   piq
# 39   89   piq
#
# [80 rows x 2 columns]

# %%
model = ols("iq ~ type", data_long).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                     iq   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.2168
# Date:                Tue, 18 Jul 2023   Prob (F-statistic):              0.643
# Time:                        17:06:38   Log-Likelihood:                -364.35
# No. Observations:                  80   AIC:                             732.7
# Df Residuals:                      78   BIC:                             737.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept     113.4500      3.683     30.807      0.000     106.119     120.781
# ...

# %% [markdown]
# #### We retrieve the same values for t-test and corresponding p-values for the effect of the type of iq than the previous t-test

# %%
stats.ttest_ind(data['FSIQ'], data['PIQ'])
# Out:
# TtestResult(statistic=0.465637596380964, pvalue=0.6427725009414841, df=78.0)

# %% [markdown]
# ## Multiple Regression: including multiple factors with iris data

# %%
data = pandas.read_csv('iris.csv')
model = ols('sepal_width ~ name + petal_length', data).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            sepal_width   R-squared:                       0.478
# Model:                            OLS   Adj. R-squared:                  0.468
# Method:                 Least Squares   F-statistic:                     44.63
# Date:                Tue, 18 Jul 2023   Prob (F-statistic):           1.58e-20
# Time:                        17:06:39   Log-Likelihood:                -38.185
# No. Observations:                 150   AIC:                             84.37
# Df Residuals:                     146   BIC:                             96.41
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept              2.9813      0.099     29.989      0.000       2.785       3.178
# ...

# %% [markdown]
# ## Post-hoc hypothesis testing: analysis of variance (ANOVA)

# %%
print(model.f_test([0, 1, -1, 0]))
# Out:
# <F test: F=3.2453353465741173, p=0.07369058781701415, df_denom=146, df_num=1>

# %% [markdown]
# ## Load the wages.txt data

# %%
if not os.path.exists('wages.txt'):
    # Download the file if it is not present
    urllib.request.urlretrieve('http://lib.stat.cmu.edu/datasets/CPS_85_Wages',
                       'wages.txt')
    # Give names to the columns
names = [
    'EDUCATION: Number of years of education',
    'SOUTH: 1=Person lives in South, 0=Person lives elsewhere',
    'SEX: 1=Female, 0=Male',
    'EXPERIENCE: Number of years of work experience',
    'UNION: 1=Union member, 0=Not union member',
    'WAGE: Wage (dollars per hour)',
    'AGE: years',
    'RACE: 1=Other, 2=Hispanic, 3=White',
    'OCCUPATION: 1=Management, 2=Sales, 3=Clerical, 4=Service, 5=Professional, 6=Other',
    'SECTOR: 0=Other, 1=Manufacturing, 2=Construction',
    'MARR: 0=Unmarried,  1=Married',
]

short_names = [n.split(':')[0] for n in names]

data = pandas.read_csv('wages.txt', skiprows=27, skipfooter=6, engine='python', sep=None,
                       header=None)
data.columns = short_names

# Log-transform the wages, because they typically are increased with multiplicative factors
data['WAGE'] = np.log10(data['WAGE'])

# %% [markdown]
# ## More visualization: seaborn for statistical exploration

# %%
print(data)
# Out:
#      EDUCATION  SOUTH  SEX  EXPERIENCE  UNION      WAGE  AGE  RACE  \
# 0            8      0    1          21      0  0.707570   35     2
# 1            9      0    1          42      0  0.694605   57     3
# 2           12      0    0           1      0  0.824126   19     3
# 3           12      0    0           4      0  0.602060   22     3
# 4           12      0    0          17      0  0.875061   35     3
# ..         ...    ...  ...         ...    ...       ...  ...   ...
# 529         18      0    0           5      0  1.055378   29     3
# 530         12      0    1          33      0  0.785330   51     1
# 531         17      0    1          25      1  1.366423   48     1
# 532         12      1    0          13      1  1.298416   31     3
# 533         16      0    0          33      0  1.186956   55     3
#
#      OCCUPATION  SECTOR  MARR
# 0             6       1     1
# 1             6       1     1
# 2             6       1     0
# 3             6       0     0
# ...

# %% [markdown]
# ### Pairplot: scatter matrices

# %%
seaborn.pairplot(data, vars=['WAGE', 'AGE', 'EDUCATION'], 
                 kind ='reg')
# Out:
# /srv/conda/envs/notebook/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
seaborn.pairplot(data, vars=['WAGE', 'AGE', 'EDUCATION'],
                 kind='reg', hue='SEX')
# Out:
# /srv/conda/envs/notebook/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### To achieve a more "modern", "excel-like" look, you can reset the default setting

# %%
plt.rcdefaults()

# %% [markdown]
# ## lmplot: plotting a univariate regression

# %%
seaborn.lmplot(y ='WAGE', x='EDUCATION', data = data)
# Out:
# /srv/conda/envs/notebook/lib/python3.9/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Testing for interactions

# %%
result = smf.ols(formula='WAGE ~ EDUCATION + SEX + EDUCATION * SEX',
                data=data).fit()    
print(result.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   WAGE   R-squared:                       0.198
# Model:                            OLS   Adj. R-squared:                  0.194
# Method:                 Least Squares   F-statistic:                     43.72
# Date:                Tue, 18 Jul 2023   Prob (F-statistic):           2.94e-25
# Time:                        17:06:59   Log-Likelihood:                 88.503
# No. Observations:                 534   AIC:                            -169.0
# Df Residuals:                     530   BIC:                            -151.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         0.5748      0.058      9.861      0.000       0.460       0.689
# ...
